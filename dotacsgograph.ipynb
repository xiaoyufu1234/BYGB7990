# %%
import urllib.request as request

# %%
import pandas as pd
import seaborn as sns

# %%
df_dota = pd.read_csv('dota2.csv')

# %%
df_dota
# Out:
#     tournament_ID           tournament_name  prize_pool  year
# 0               1    The International 2019    34330069  2019
# 1               2    The International 2018    25532177  2018
# 2               3    The International 2017    24687919  2017
# 3               4    The International 2016    20770460  2016
# 4               5    The International 2015    18429613  2015
# 5               6    The International 2014    10931103  2014
# 6               7                  DAC 2015     3057521  2015
# 7               8     The Boston Major 2016     3000000  2016
# 8               9  The Frankfurt Major 2015     3000000  2015
# 9              10       The Kiev Major 2017     3000000  2017
# 10             11     The Manila Major 2016     3000000  2016
# 11             12   The Shanghai Major 2016     3000000  2016
# 12             13    The International 2013     2874381  2013
# 13             14    The International 2011     1600000  2011
# ...

# %%
x_var = 'year'
y_var = 'prize_pool'
df.plot.scatter(x=x_var, y=y_var, legend=False)

# %%
df_csgo = pd.read_csv('csgo.csv')
df_csgo
# Out:
#     tournament_ID                        tournament_name  prize_pool  year
# 0               1                      WESG 2016 (CS:GO)     1500000  2016
# 1               2                 WESG 2017 (CS:GO Male)     1500000  2017
# 2               3                       ELEAGUE Season 1     1410000  2016
# 3               4                       ELEAGUE Season 2     1100000  2016
# 4               5             ELEAGUE CS:GO Premier 2017     1000000  2017
# 5               6             ELEAGUE CS:GO Premier 2018     1000000  2018
# 6               7                     ELEAGUE Major 2017     1000000  2017
# 7               8             ELEAGUE Major: Boston 2018     1000000  2018
# 8               9                  ESL One: Cologne 2016     1000000  2016
# 9              10              FACEIT Major: London 2018     1000000  2018
# 10             11                    FLASHPOINT Season 1     1000000  2020
# ...

# %%
x_var = 'year'
y_var = 'prize_pool'
df_csgo.plot.scatter(x=x_var, y=y_var, legend=False)

# %%
df_dotagraph = pd.read_csv('dotagraph.csv')
df_dotagraph
# Out:
#       Month  average_viewers(k)
# 0   12/2016                60.3
# 1   01/2017                52.6
# 2   02/2017                47.7
# 3   03/2017                51.6
# 4   04/2017                68.1
# 5   05/2017                46.6
# 6   06/2017                57.7
# 7   07/2017                32.8
# 8   08/2017                78.7
# 9   09/2017                40.3
# 10  10/2017                42.5
# 11  11/2017                55.0
# 12  12/2017                43.4
# 13  01/2018                41.6
# 14  02/2018                49.0
# 15  03/2018                53.6
# 16  04/2018                55.8
# 17  05/2018                52.5
# 18  06/2018                66.8
# 19  07/2018                39.0
# 20  08/2018                94.0
# 21  09/2018                41.3
# 22  10/2018                47.3
# 23  11/2018                64.1
# 24  12/2018                44.3
# 25  01/2019                62.5
# 26  02/2019                74.9
# 27  03/2019                67.5
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

# %%
bar = (
    Bar()
    .add_xaxis(df_dotagraph['Month'].to_list())
    .add_yaxis('average_viewers(k)',df_dotagraph['average_viewers(k)'].to_list())
    .set_global_opts(title_opts=opts.TitleOpts(title="Average Number of viewers"))
)

# %%
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8a272b0c56474d22bf7b934ab9ef6df2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8a272b0c56474d22bf7b934ab9ef6df2 = echarts.init(
#                     document.getElementById('8a272b0c56474d22bf7b934ab9ef6df2'), 'white', {renderer: 'canvas'});
#                 var option_8a272b0c56474d22bf7b934ab9ef6df2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
